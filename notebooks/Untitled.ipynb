# %%
import opengrid as og
og.datasets.list_available()
# Out:
# {'elec_power_min_1sensor': '/home/roel/work/opengrid/code/og/opengrid/datasets/elec_power_min_1sensor.pkl',
#  'electricity_2016_hour': '/home/roel/work/opengrid/code/og/opengrid/datasets/electricity_2016_hour.pkl',
#  'gas_2016_hour': '/home/roel/work/opengrid/code/og/opengrid/datasets/gas_2016_hour.pkl',
#  'gas_dec2016_min': '/home/roel/work/opengrid/code/og/opengrid/datasets/gas_dec2016_min.pkl',
#  'water_2016_hour': '/home/roel/work/opengrid/code/og/opengrid/datasets/water_2016_hour.pkl',
#  'water_march2015_min': '/home/roel/work/opengrid/code/og/opengrid/datasets/water_march2015_min.pkl',
#  'weather_2016_hour': '/home/roel/work/opengrid/code/og/opengrid/datasets/weather_2016_hour.pkl'}

# %%
df = og.datasets.get('water_march2015_min')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44580 entries, 2015-03-01 00:00:00+01:00 to 2015-03-31 23:59:00+02:00
# Freq: T
# Data columns (total 7 columns):
# 6616    44510 non-null float64
# b285    44576 non-null float64
# 2923    44565 non-null float64
# a805    44139 non-null float64
# 1a5c    44514 non-null float64
# a926    44575 non-null float64
# a519    44566 non-null float64
# dtypes: float64(7)
# memory usage: 2.7 MB

# %%
plt = og.plot_style()
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc666c53e48>,
# ...
#       dtype=object)
